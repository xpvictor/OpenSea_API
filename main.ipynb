# %%
import requests
import json
import pandas as pd
import time
from dotenv import load_dotenv
import os
import re

# %%
load_dotenv()

slug_collection = 'boredape-baseclub'
initial_token = 'LXBrPTE4ODI3MTg3NTQ='

url = f'https://api.opensea.io/api/v2/collection/{slug_collection}/nfts?limit=200'
api_key = os.getenv('api_key')


headers = {
    "accept": "application/json",
    "x-api-key": api_key
}

response = requests.get(url,headers= headers).json()
#response.raise_for_status() <-- used for make a validation about status 
df_start = pd.json_normalize(response['nfts'])

# %%
df_boredape_baseclub = pd.read_json("./datasource/boredape-baseclub.json")

df_boredape_baseclub = pd.concat([df_start,df_boredape_baseclub])
df_boredape_baseclub['identifier'] = df_boredape_baseclub['identifier'].astype(str)
df_boredape_baseclub.sort_values(by=['identifier'], ascending=False)

display(df_boredape_baseclub)
# Out:
#      identifier         collection  \
# 0         10000  boredape-baseclub
# 1          9999  boredape-baseclub
# 2          9998  boredape-baseclub
# 3          9995  boredape-baseclub
# 4          9993  boredape-baseclub
# ...         ...                ...
# 9945        581  boredape-baseclub
# 9946        323  boredape-baseclub
# 9947        242  boredape-baseclub
# 9948        208  boredape-baseclub
# 9949        699  boredape-baseclub
#
#                                         contract token_standard         name  \
# 0     0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721  BABC #10000
# 1     0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721   BABC #9999
# 2     0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721   BABC #9998
# 3     0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721   BABC #9995
# 4     0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721   BABC #9993
# ...                                          ...            ...          ...
# 9945  0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721    BABC #581
# 9946  0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721    BABC #323
# 9947  0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721    BABC #242
# 9948  0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721    BABC #208
# 9949  0x0be0bb1097f4465b17b1ac3b22b5427d9cbf6d2c         erc721    BABC #699
#
#                                             description  \
# 0     Discover the world of the Bored Ape Base Club ...
# 1     Discover the world of the Bored Ape Base Club ...
# 2     Discover the world of the Bored Ape Base Club ...
# 3     Discover the world of the Bored Ape Base Club ...
# 4     Discover the world of the Bored Ape Base Club ...
# ...                                                 ...
# 9945  Discover the world of the Bored Ape Base Club ...
# 9946  Discover the world of the Bored Ape Base Club ...
# 9947  Discover the world of the Bored Ape Base Club ...
# 9948  Discover the world of the Bored Ape Base Club ...
# 9949  Discover the world of the Bored Ape Base Club ...
#
#                                               image_url  \
# 0     https://ipfs.io/ipfs/bafybeie7bmzytv3svlakivbt...
# 1     https://ipfs.io/ipfs/bafybeie7bmzytv3svlakivbt...
# 2     https://ipfs.io/ipfs/bafybeie7bmzytv3svlakivbt...
# 3     https://ipfs.io/ipfs/bafybeie7bmzytv3svlakivbt...
# 4     https://ipfs.io/ipfs/bafybeie7bmzytv3svlakivbt...
# ...                                                 ...
# 9945  https://ipfs.io/ipfs/bafybeibeiujqlvv63dkqlz2v...
# 9946  https://ipfs.io/ipfs/bafybeie2lizycnhw2pc46yvi...
# 9947  https://ipfs.io/ipfs/bafybeie2lizycnhw2pc46yvi...
# 9948  https://ipfs.io/ipfs/bafybeie2lizycnhw2pc46yvi...
# 9949  https://ipfs.io/ipfs/bafybeia3k34shqinmb6kkscu...
#
#                                       display_image_url display_animation_url  \
# 0     https://i.seadn.io/s/raw/files/ba756feb99759e0...                  None
# 1     https://i.seadn.io/s/raw/files/f9bdbfeb55348f9...                  None
# 2     https://i.seadn.io/s/raw/files/e75fa60e4c31ec3...                  None
# 3     https://i.seadn.io/s/raw/files/155e3a7c190928a...                  None
# 4     https://i.seadn.io/s/raw/files/aeaac3475e3571d...                  None
# ...                                                 ...                   ...
# 9945  https://i.seadn.io/s/raw/files/830c402bb227813...                   NaN
# 9946  https://i.seadn.io/s/raw/files/b5920d7157a8b63...                   NaN
# 9947  https://i.seadn.io/s/raw/files/e4c81af8aa4a460...                   NaN
# 9948  https://i.seadn.io/s/raw/files/cfca57ff1b698f7...                   NaN
# 9949  https://i.seadn.io/s/raw/files/ce93cb4ec0825b4...                   NaN
#
#                                            metadata_url  \
# 0     https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 1     https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 2     https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 3     https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 4     https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# ...                                                 ...
# 9945  https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 9946  https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 9947  https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 9948  https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
# 9949  https://ipfs.io/ipfs/bafybeiacrqba67k6p7vu523m...
#
#                                             opensea_url  \
# 0     https://opensea.io/assets/base/0x0be0bb1097f44...
# 1     https://opensea.io/assets/base/0x0be0bb1097f44...
# 2     https://opensea.io/assets/base/0x0be0bb1097f44...
# 3     https://opensea.io/assets/base/0x0be0bb1097f44...
# 4     https://opensea.io/assets/base/0x0be0bb1097f44...
# ...                                                 ...
# 9945  https://opensea.io/assets/base/0x0be0bb1097f44...
# 9946  https://opensea.io/assets/base/0x0be0bb1097f44...
# 9947  https://opensea.io/assets/base/0x0be0bb1097f44...
# 9948  https://opensea.io/assets/base/0x0be0bb1097f44...
# 9949  https://opensea.io/assets/base/0x0be0bb1097f44...
#
#                       updated_at  is_disabled  is_nsfw
# 0     2024-07-30T01:53:09.654747        False    False
# 1     2024-12-01T21:17:06.530962        False    False
# 2     2024-08-02T22:16:48.632647        False    False
# 3     2024-11-26T05:59:57.380577        False    False
# 4     2024-11-26T05:59:57.530117        False    False
# ...                          ...          ...      ...
# 9945  2024-07-30 00:16:10.159199        False    False
# 9946  2024-07-30 00:35:51.212009        False    False
# 9947  2024-06-28 14:00:30.172239        False    False
# 9948  2024-11-12 17:24:08.771465        False    False
# 9949  2024-11-16 19:10:40.938775        False    False
#
# [10150 rows x 14 columns]

# %%
#df_boredape_baseclub['identifier'] =
